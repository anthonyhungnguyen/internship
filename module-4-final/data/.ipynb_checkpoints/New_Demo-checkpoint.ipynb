# %% [markdown]
# # Import Preprocess Data, Libraries

# %%
import pandas as pd
from pyArango.connection import Connection

# %%
df = pd.read_csv('./processed_data.csv', low_memory=False)
df.head()
# Out:
#     timestamp           userId                         hw_released  \
# 0  1596244856  170425000002238  Tue Jul 07 08:50:39 GMT+07:00 2020
# 1  1596244830  191113586003363  Thu Jul 02 12:19:14 GMT+07:00 2020
# 2  1596244888  200413000001404  Thu Dec 07 11:24:05 GMT+07:00 2017
# 3  1596244831  200428000037320  Wed Apr 22 07:53:33 GMT+07:00 2020
# 4  1596244849  190309000002524  Thu Mar 12 12:05:05 GMT+07:00 2020
#
#        hw_device_id        hw_cpu_name hw_screen_aspect_ratio  \
# 0  f21ebb2f9064b16e         exynos9810                      2
# 1  13cf342d200936c8             hi6250                      1
# 2  b41f717314855504             sc8830                      1
# 3  8d36707898c6955d  samsungexynos9810                      2
# 4  af1934dafd8aba01             mt6757                      1
#
#   hw_screen_pixel_density                                    system_packages  \
# 0                 420 Dpi  ['com.samsung.android.provider.filterprovider'...
# 1                 320 Dpi  ['com.huawei.hifolder', 'com.android.cts.priv....
# 2                 320 Dpi  ['com.monotype.android.font.rosemary', 'com.se...
# 3                 420 Dpi  ['com.samsung.android.provider.filterprovider'...
# 4                 420 Dpi  ['com.samsung.android.provider.filterprovider'...
#
#   network_wifi_mac_address hw_screen_resolution  ... hw_ram_total  \
# 0        12:2F:14:33:9D:E7            1080x2400  ...      7,94 GB
# 1        A8:E5:44:0E:BD:BB            1200x1920  ...      2,88 GB
# 2        AC:AF:B9:61:36:C8             720x1280  ...      1,33 GB
# 3        24:18:1D:FE:E3:E0            1080x2220  ...      5,89 GB
# 4        A4:6C:F1:C3:34:4E            1080x1920  ...      3.92 GB
#
#   hw_cpu_min_speed hw_storage_total  \
# 0         455000Hz           118 GB
# 1         480000Hz         25,23 GB
# 2         768000Hz          4,79 GB
# 3         455000Hz           120 GB
# 4         247000Hz         26.75 GB
#
#                                         list_of_wifi  \
# 0                                               ['']
# 1  ['Dinh1', 'MaiCa', 'NhuQuynh', 'Support', 'Nam...
# 2  ['Xiaomi_70BE_8F41', 'COM TAM SONG ANH', 'Redm...
# 3                                               ['']
# 4  ['NamCoffee&Milktea', 'YÊU MỘT NGƯỜI', 'Studio...
#
#    hw_camera_front_max_photo_resolution hw_camera_back_max_video_resolution  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                             2576x1932                           3264x2448
# 3                                   NaN                                 NaN
# 4                             4608x3456                           4128x3096
#
#                                             ringtone hw_camera_number_camera  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2  ['Basic Bell', 'Basic Tone', 'Beep Once', 'Bee...                     2.0
# 3                                                NaN                     NaN
# 4                                                NaN                     2.0
#
#   hw_camera_back_max_photo_resolution hw_camera_front_max_video_resolution
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                           3264x2448                            2576x1932
# 3                                 NaN                                  NaN
# 4                           4128x3096                            4608x3456
#
# [5 rows x 38 columns]

# %% [markdown]
# # Connect to ArangoDB, DB and collections

# %%
conn = Connection(username='root', password='ngph')
db = conn['final']
users = db['users']
devices = db['devices']
user_device = db['user_device']
device_deviceModel = db['device_devicemodel']
device_model = db['device_model']

# %% [markdown]
# # Insert data into ArangoDB

# %% [markdown]
# ## Add users

# %%
unique_users = df['userId'].unique()

# %%
for uu in unique_users:
    users.createDocument({
        '_key': uu
    }).save()

# %% [markdown]
# ## Add latest devices info

# %%
devices_latest = df[df.groupby(['hw_device_id'])['timestamp'].transform(max) == df['timestamp']]

# %%
for _, row in devices_latest[:10].iterrows():
    print()
# Out:
# ['[', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', '.', 'f', 'i', 'l', 't', 'e', 'r', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'D', 'a', 't', 'a', 'C', 'r', 'e', 'a', 't', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 't', 's', '.', 'p', 'r', 'i', 'v', '.', 'c', 't', 's', 's', 'h', 'i', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 's', 'm', 'a', 'r', 't', 's', 'w', 'i', 't', 'c', 'h', 'a', 's', 's', 'i', 's', 't', 'a', 'n', 't', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'v', 's', 'i', 'm', '.', 'e', 'r', 'i', 'c', 's', 's', 'o', 'n', 'n', 's', 'd', 's', '.', 'w', 'e', 'b', 'a', 'p', 'p', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 's', 'e', 't', 'u', 'p', 'w', 'i', 'z', 'a', 'r', 'd', 'l', 'e', 'g', 'a', 'l', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'g', 'a', 'l', 'a', 'x', 'y', 'f', 'i', 'n', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'l', 'o', 'c', 'a', 't', 'i', 'o', 'n', '.', 'n', 's', 'f', 'l', 'p', '2', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'h', 'e', 'm', 'e', 's', 't', 'o', 'r', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'c', 'h', 'r', 'o', 'm', 'e', 'c', 'u', 's', 't', 'o', 'm', 'i', 'z', 'a', 't', 'i', 'o', 'n', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'a', 'o', 'd', 's', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'c', 'o', 'c', 'k', 't', 'a', 'i', 'l', 'b', 'a', 'r', 's', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'c', 'o', 'r', 'n', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 's', 'u', 'w', 's', 'c', 'r', 'i', 'p', 't', 'p', 'l', 'a', 'y', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'd', 'o', 'u', 'b', 'l', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'l', 'o', 'c', 'a', 't', 'i', 'o', 'n', '.', 'n', 'f', 'w', 'l', 'o', 'c', 'a', 't', 'i', 'o', 'n', 'p', 'r', 'i', 'v', 'a', 'c', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'm', 'i', 'c', 'r', 'o', 's', 'o', 'f', 't', '.', 'a', 'p', 'p', 'm', 'a', 'n', 'a', 'g', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', 'h', 'o', 'n', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', ...
# ['[', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'f', 'o', 'l', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 't', 's', '.', 'p', 'r', 'i', 'v', '.', 'c', 't', 's', 's', 'h', 'i', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'c', 'a', 'm', 'e', 'r', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'l', 'a', 'u', 'n', 'c', 'h', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'm', 'e', 'd', 'i', 'a', 'c', 'e', 'n', 't', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', 'h', 'o', 'n', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'g', 'o', 'o', 'g', 'l', 'e', 'q', 'u', 'i', 'c', 'k', 's', 'e', 'a', 'r', 'c', 'h', 'b', 'o', 'x', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'c', 'a', 'l', 'e', 'n', 'd', 'a', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'd', 'i', 's', 'k', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'v', 'i', 'e', 'w', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'z', 'i', 'n', 'g', '.', 'z', 'a', 'l', 'o', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'i', 'a', 'w', 'a', 'r', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'b', 'l', 'u', 'e', 't', 'o', 'o', 't', 'h', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'm', 'e', 'd', 'i', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 't', 'o', 'u', 'c', 'h', 't', 'y', 'p', 'e', '.', 's', 'w', 'i', 'f', 't', 'k', 'e', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'h', 'e', 'm', 'e', 'm', 'a', 'n', 'a', 'g', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 'h', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'h', 's', 'f', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'o', 'n', 'e', 't', 'i', 'm', 'e', 'i', 'n', 'i', 't', 'i', 'a', 'l', 'i', 'z', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'h', 'a', 'r', 'e', 'd', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'k', 'i', 'd', 's', 'm', 'o', 'd', 'e', '.', 'k', 'i', 'd', 's', 'p', 'a', 'i', 'n', 't', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'u', 't', 'o', 'i', 'n', 's', 't', 'a', 'l', 'l', 'a', 'p', 'k', 'f', 'r', 'o', 'm', 'm', 'c', 'c', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'w', 'a', 'l', 'l', 'p', 'a', 'p', 'e', 'r', 'c', 'r', 'o', 'p', 'p', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'b', 'e', 'n', 'q', 'u', '.', 'w', 'u', 't', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'n', 'e', 'a', 'r', 'b', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'F', 'l', 'o', 'a', 't', 'T', ...
# ['[', "'", 'c', 'o', 'm', '.', 'm', 'o', 'n', 'o', 't', 'y', 'p', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'f', 'o', 'n', 't', '.', 'r', 'o', 's', 'e', 'm', 'a', 'r', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'D', 'a', 't', 'a', 'C', 'r', 'e', 'a', 't', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'k', 'y', 'p', 'e', '.', 'r', 'a', 'i', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'h', 'e', 'm', 'e', 's', 't', 'o', 'r', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'c', 'h', 'r', 'o', 'm', 'e', 'c', 'u', 's', 't', 'o', 'm', 'i', 'z', 'a', 't', 'i', 'o', 'n', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', 'h', 'o', 'n', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'p', 'a', 'r', 's', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'g', 'o', 'o', 'g', 'l', 'e', 'q', 'u', 'i', 'c', 'k', 's', 'e', 'a', 'r', 'c', 'h', 'b', 'o', 'x', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'c', 'a', 'l', 'e', 'n', 'd', 'a', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'o', 's', 'p', '.', 'a', 'p', 'p', '.', 's', 'i', 'g', 'n', 'i', 'n', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'c', 'l', 'i', 'p', 'b', 'o', 'a', 'r', 'd', 's', 'a', 'v', 'e', 's', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'u', 't', 'o', 'm', 'a', 't', 'i', 'o', 'n', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'z', 'i', 'n', 'g', '.', 'z', 'a', 'l', 'o', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'm', 'e', 'd', 'i', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'k', 'a', 't', 'e', 'c', 'c', 'a', '.', 's', 'c', 'r', 'e', 'e', 'n', 'o', 'f', 'f', 'l', 'o', 'c', 'k', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 's', 'd', 'k', '.', 's', 'p', 'e', 'n', 'v', '1', '0', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'o', 'n', 'e', 't', 'i', 'm', 'e', 'i', 'n', 'i', 't', 'i', 'a', 'l', 'i', 'z', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'w', 'i', 'd', 'g', 'e', 't', 'a', 'p', 'p', '.', 'd', 'i', 'g', 'i', 't', 'a', 'l', 'c', 'l', 'o', 'c', 'k', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'w', 'a', 'l', 'l', 'p', 'a', 'p', 'e', 'r', 'c', 'r', 'o', 'p', 'p', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'f', 'a', 'c', 't', 'o', 'r', 'y', '.', 'c', 'a', 'm', 'e', 'r', 'a', "'", ',', ' ', "'", 'o', 'r', 'g', '.', 's', 'i', 'm', 'a', 'l', 'l', 'i', 'a', 'n', 'c', 'e', '.', 'o', 'p', 'e', 'n', 'm', 'o', 'b', 'i', 'l', 'e', 'a', 'p', 'i', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'u', 's', 'b', 's', 'e', 't', 't', 'i', 'n', 'g', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'd', 'o', 'c', 'u', 'm', 'e', 'n', 't', 's', 'u', 'i', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', 'e', 'r', 'n', 'a', 'l', 's', 't', 'o', 'r', 'a', 'g', 'e', "'", ',', ' ', "'", 'c', ...
# ['[', "'", 'v', 'n', '.', 'c', 'o', 'm', '.', 'm', 'i', 's', 'a', '.', 's', 'o', 't', 'h', 'u', 'c', 'h', 'i', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', '.', 'f', 'i', 'l', 't', 'e', 'r', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'm', 'o', 'n', 'o', 't', 'y', 'p', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'f', 'o', 'n', 't', '.', 'r', 'o', 's', 'e', 'm', 'a', 'r', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'D', 'a', 't', 'a', 'C', 'r', 'e', 'a', 't', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'k', 'y', 'p', 'e', '.', 'r', 'a', 'i', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 't', 's', '.', 'p', 'r', 'i', 'v', '.', 'c', 't', 's', 's', 'h', 'i', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'w', 'i', 'd', 'g', 'e', 't', 'a', 'p', 'p', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', 'a', 'p', 'p', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'g', 'a', 'l', 'a', 'x', 'y', 'f', 'i', 'n', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'l', 'o', 'c', 'a', 't', 'i', 'o', 'n', '.', 'n', 's', 'f', 'l', 'p', '2', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'h', 'e', 'm', 'e', 's', 't', 'o', 'r', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'c', 'h', 'r', 'o', 'm', 'e', 'c', 'u', 's', 't', 'o', 'm', 'i', 'z', 'a', 't', 'i', 'o', 'n', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'a', 'o', 'd', 's', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'g', 'o', 'd', 'a', '.', 'm', 'o', 'b', 'i', 'l', 'e', '.', 'c', 'o', 'n', 's', 'u', 'm', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', 'h', 'o', 'n', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'p', 'a', 'r', 's', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 's', 'v', 'o', 'i', 'c', 'e', '.', 's', 'y', 'n', 'c', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', 'l', 'o', 'c', 'k', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'g', 'o', 'o', 'g', 'l', 'e', 'q', 'u', 'i', 'c', 'k', 's', 'e', 'a', 'r', 'c', 'h', 'b', 'o', 'x', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 'a', 'l', 'e', 'n', 'd', 'a', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'v', 'n', 'p', 'a', 'y', '.', 'm', 'e', 'r', 'c', 'h', 'a', 'n', 't', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'c', 'a', 'l', 'e', 'n', 'd', 'a', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'o', 's', 'p', '.', 'a', 'p', 'p', '.', 's', 'i', 'g', 'n', 'i', 'n', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', ...
# ['[', "'", 'c', 'o', 'm', '.', 's', 'k', 'y', 'p', 'e', '.', 'r', 'a', 'i', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 't', 's', '.', 'p', 'r', 'i', 'v', '.', 'c', 't', 's', 's', 'h', 'i', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 's', 'u', 's', '.', 's', 'y', 's', 't', 'e', 'm', '.', 'a', 'p', 'i', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'c', 'o', 'r', 'n', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 's', 'u', 's', '.', 'z', 'e', 'n', 'u', 'i', '.', 'l', 'i', 'v', 'e', 'w', 'a', 'l', 'l', 'p', 'a', 'p', 'e', 'r', '.', 'y', 'o', 'd', 'a', 'l', 'i', 'v', 'e', 'w', 'a', 'l', 'l', 'p', 'a', 'p', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'o', 'a', 's', 'i', 's', 'f', 'e', 'n', 'g', '.', 'g', 'r', 'e', 'e', 'n', 'i', 'f', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'd', 'o', 'u', 'b', 'l', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', 'h', 'o', 'n', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'd', 'y', 'n', 's', 'y', 's', 't', 'e', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'd', 'a', 't', 'h', 'v', 'i', 'o', 's', '.', 'i', 'n', 'l', 'o', 'v', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'a', 'l', 'f', 'b', 'r', 'i', 'c', 'k', '.', 'f', 'r', 'u', 'i', 't', 'n', 'i', 'n', 'j', 'a', 'f', 'r', 'e', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 's', 'u', 's', '.', 'm', 'o', 'b', 'i', 'l', 'e', 'm', 'a', 'n', 'a', 'g', 'e', 'r', 's', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'g', 'o', 'o', 'g', 'l', 'e', 'q', 'u', 'i', 'c', 'k', 's', 'e', 'a', 'r', 'c', 'h', 'b', 'o', 'x', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 's', 'u', 's', '.', 'a', 's', 'u', 's', 'i', 'n', 'c', 'a', 'l', 'l', 'u', 'i', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'c', 'a', 'l', 'e', 'n', 'd', 'a', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', 's', '.', 'g', 'o', 'o', 'g', 'l', 'e', 'a', 's', 's', 'i', 's', 't', 'a', 'n', 't', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'f', 'a', 's', 't', 'a', 'c', 'a', 's', 'h', '.', 't', 'c', 'b', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'z', 'i', 'n', 'g', '.', 'z', 'a', 'l', 'o', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'm', 'e', 'd', 'i', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 's', 'u', 's', '.', 'w', 'e', 'a', 't', 'h', 'e', 'r', 't', 'i', 'm', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'h', 'e', 'm', 'e', '.', 'i', 'c', 'o', 'n', '.', 's', 'q', 'u', 'a', 'r', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'o', 'n', 'e', 't', 'i', 'm', 'e', 'i', 'n', 'i', 't', 'i', 'a', 'l', 'i', 'z', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', ...
# ['[', "'", 'c', 'o', 'm', '.', 'w', 'e', 'i', 'c', 'o', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 't', 'i', 'o', 'n', 'a', 'l', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'e', 'v', 'e', 'n', 'w', 'e', 'l', 'l', '.', 'D', 'b', 'g', 'C', 'f', 'g', 'T', 'o', 'o', 'l', '.', 'o', 'v', 'e', 'r', 'l', 'a', 'y', '.', 'b', 'a', 's', 'e', '.', 's', '6', '0', '0', 'w', 'w', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 't', 's', '.', 'p', 'r', 'i', 'v', '.', 'c', 't', 's', 's', 'h', 'i', 'm', "'", ',', ' ', "'", 's', 'c', 'r', 'e', 'e', 'n', 'r', 'e', 'c', 'o', 'r', 'd', 'e', 'r', '.', 'r', 'e', 'c', 'o', 'r', 'd', 'e', 'r', '.', 'e', 'd', 'i', 't', 'o', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'e', 'v', 'e', 'n', 'w', 'e', 'l', 'l', '.', 'S', 'e', 't', 'u', 'p', 'W', 'i', 'z', 'a', 'r', 'd', '.', 'o', 'v', 'e', 'r', 'l', 'a', 'y', '.', 'b', 'a', 's', 'e', '.', 's', '6', '0', '0', 'w', 'w', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'c', 'o', 'r', 'n', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'd', 'o', 'u', 'b', 'l', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', 'h', 'o', 'n', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'd', 'y', 'n', 's', 'y', 's', 't', 'e', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'g', 'o', 'o', 'g', 'l', 'e', 'q', 'u', 'i', 'c', 'k', 's', 'e', 'a', 'r', 'c', 'h', 'b', 'o', 'x', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'm', 'd', 'g', 'l', 'o', 'b', 'a', 'l', '.', 'd', 'a', 't', 'a', 'g', 'o', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 't', '7', '.', 'b', 'u', 's', 'm', 'a', 'p', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'c', 'a', 'l', 'e', 'n', 'd', 'a', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'z', 'i', 'n', 'g', '.', 'z', 'a', 'l', 'o', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'm', 'e', 'd', 'i', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'e', 'v', 'e', 'n', 'w', 'e', 'l', 'l', '.', 'p', 'h', 'o', 'n', 'e', '.', 'o', 'v', 'e', 'r', 'l', 'a', 'y', '.', 'b', 'a', 's', 'e', '.', 's', '6', '0', '0', 'w', 'w', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'h', 'e', 'm', 'e', '.', 'i', 'c', 'o', 'n', '.', 's', 'q', 'u', 'a', 'r', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'o', 'n', 'e', 't', 'i', 'm', 'e', 'i', 'n', 'i', 't', 'i', 'a', 'l', 'i', 'z', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'h', 'a', 'r', 'e', 'd', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 's', 'y', 's', 't', 'e', 'm', 'u', 'i', '.', 'n', 'a', 'v', 'b', 'a', 'r', '.', 'g', 'e', 's', 't', 'u', 'r', 'a', 'l', '_', 'w', 'i', 'd', 'e', '_', 'b', 'a', 'c', 'k', "'", ',', ' ', ...
# ['[', "'", 'c', 'o', 'm', '.', 'm', 'i', 'u', 'i', '.', 's', 'c', 'r', 'e', 'e', 'n', 'r', 'e', 'c', 'o', 'r', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 't', 's', '.', 'p', 'r', 'i', 'v', '.', 'c', 't', 's', 's', 'h', 'i', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'q', 'u', 'a', 'l', 'c', 'o', 'm', 'm', '.', 'q', 't', 'i', '.', 'p', 'e', 'r', 'f', 'd', 'u', 'm', 'p', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'c', 'o', 'r', 'n', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'd', 'o', 'u', 'b', 'l', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', 'h', 'o', 'n', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'm', 'i', 'u', 'i', '.', 'p', 'o', 'w', 'e', 'r', 'k', 'e', 'e', 'p', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'd', 'i', 'x', '.', 'f', 'i', 'n', 'g', 'e', 'r', 'p', 'r', 'i', 'n', 't', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'x', 'i', 'a', 'o', 'm', 'i', '.', 'm', 'i', 'p', 'l', 'a', 'y', '_', 'c', 'l', 'i', 'e', 'n', 't', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'g', 'o', 'o', 'g', 'l', 'e', 'q', 'u', 'i', 'c', 'k', 's', 'e', 'a', 'r', 'c', 'h', 'b', 'o', 'x', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'm', 'i', 'u', 'i', '.', 'f', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'm', 'i', 'u', 'i', '.', 'q', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'c', 'a', 'l', 'e', 'n', 'd', 'a', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'z', 'i', 'n', 'g', '.', 'z', 'a', 'l', 'o', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'm', 'e', 'd', 'i', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'm', 'i', 'l', 'i', 'n', 'k', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'o', 'n', 'e', 't', 'i', 'm', 'e', 'i', 'n', 'i', 't', 'i', 'a', 'l', 'i', 'z', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'h', 'a', 'r', 'e', 'd', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'x', 'i', 'a', 'o', 'm', 'i', '.', 'p', 'o', 'w', 'e', 'r', 'c', 'h', 'e', 'c', 'k', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'x', 'i', 'a', 'o', 'm', 'i', '.', 'a', 'c', 'c', 'o', 'u', 'n', 't', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'n', 'i', 'k', 's', 'o', 'f', 't', 'w', 'a', 'r', 'e', '.', 's', 'n', 'a', 'p', 's', 'e', 'e', 'd', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'w', 'a', 'l', 'l', 'p', 'a', 'p', 'e', 'r', 'c', 'r', 'o', 'p', 'p', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'q', 'u', 'i', 'c', 'i', 'n', 'c', '.', 'c', 'n', 'e', '.', 'C', 'N', 'E', 'S', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'b', 'e', 'n', 'q', 'u', '.', 'w', 'u', 't', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'x', 'i', 'a', 'o', 'm', 'i', '.', 'm', ...
# ['[', "'", 'o', 'r', 'g', '.', 'j', 'i', 't', 's', 'i', '.', 'm', 'e', 'e', 't', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', '.', 'f', 'i', 'l', 't', 'e', 'r', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'D', 'a', 't', 'a', 'C', 'r', 'e', 'a', 't', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 't', 's', '.', 'p', 'r', 'i', 'v', '.', 'c', 't', 's', 's', 'h', 'i', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 's', 'm', 'a', 'r', 't', 's', 'w', 'i', 't', 'c', 'h', 'a', 's', 's', 'i', 's', 't', 'a', 'n', 't', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'v', 's', 'i', 'm', '.', 'e', 'r', 'i', 'c', 's', 's', 'o', 'n', 'n', 's', 'd', 's', '.', 'w', 'e', 'b', 'a', 'p', 'p', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 's', 'e', 't', 'u', 'p', 'w', 'i', 'z', 'a', 'r', 'd', 'l', 'e', 'g', 'a', 'l', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'g', 'a', 'l', 'a', 'x', 'y', 'f', 'i', 'n', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'l', 'o', 'c', 'a', 't', 'i', 'o', 'n', '.', 'n', 's', 'f', 'l', 'p', '2', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'h', 'e', 'm', 'e', 's', 't', 'o', 'r', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'c', 'h', 'r', 'o', 'm', 'e', 'c', 'u', 's', 't', 'o', 'm', 'i', 'z', 'a', 't', 'i', 'o', 'n', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'a', 'o', 'd', 's', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'a', 'm', 's', 'u', 'n', 'g', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 'c', 'o', 'c', 'k', 't', 'a', 'i', 'l', 'b', 'a', 'r', 's', 'e', 'r', 'v', 'i', 'c', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'c', 'o', 'r', 'n', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', '.', 's', 'u', 'w', 's', 'c', 'r', 'i', 'p', 't', 'p', 'l', 'a', 'y', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'i', 'n', 't', 'e', 'r', 'n', 'a', 'l', '.', 'd', 'i', 's', 'p', 'l', 'a', 'y', '.', 'c', 'u', 't', 'o', 'u', 't', '.', 'e', 'm', 'u', 'l', 'a', 't', 'i', 'o', 'n', '.', 'd', 'o', 'u', 'b', 'l', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 's', 'e', 'c', '.', 'l', 'o', 'c', 'a', 't', 'i', 'o', 'n', '.', 'n', 'f', 'w', 'l', 'o', 'c', 'a', 't', 'i', 'o', 'n', 'p', 'r', 'i', 'v', 'a', 'c', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'm', 'i', 'c', 'r', 'o', 's', 'o', 'f', 't', '.', 'a', 'p', 'p', 'm', 'a', 'n', 'a', 'g', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', ...
# ['[', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'f', 'o', 'l', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 't', 's', '.', 'p', 'r', 'i', 'v', '.', 'c', 't', 's', 's', 'h', 'i', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'v', 'n', '.', 'c', 'o', 'o', 'k', 'y', '.', 'c', 'o', 'o', 'k', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'c', 'a', 'm', 'e', 'r', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'i', 'p', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'p', 'p', '4', 'g', 'i', 'r', 'l', '.', 'p', 'h', 'o', 't', 'o', 'c', 'o', 'l', 'l', 'a', 'g', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 's', 'y', 'n', 'e', 'r', 'g', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'l', 'a', 'u', 'n', 'c', 'h', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'm', 'e', 'd', 'i', 'a', 'c', 'e', 'n', 't', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', 'h', 'o', 'n', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'g', 'o', 'o', 'g', 'l', 'e', 'q', 'u', 'i', 'c', 'k', 's', 'e', 'a', 'r', 'c', 'h', 'b', 'o', 'x', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'c', 'a', 'l', 'e', 'n', 'd', 'a', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'f', 'e', 'a', 't', 'u', 'r', 'e', 'l', 'a', 'y', 'e', 'r', '.', 'f', 'e', 'a', 't', 'u', 'r', 'e', 'f', 'r', 'a', 'm', 'e', 'w', 'o', 'r', 'k', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'r', 'i', 'd', 'e', 'm', 'o', 'd', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'e', 'a', 'l', 't', 'h', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'c', 'a', 'r', 'd', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'd', 'i', 's', 'k', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'v', 'i', 'e', 'w', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'z', 'i', 'n', 'g', '.', 'z', 'a', 'l', 'o', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'i', 'a', 'w', 'a', 'r', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'b', 'l', 'u', 'e', 't', 'o', 'o', 't', 'h', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'm', 'e', 'd', 'i', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 't', 'o', 'u', 'c', 'h', 't', 'y', 'p', 'e', '.', 's', 'w', 'i', 'f', 't', 'k', 'e', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', 's', '.', 'd', 'o', 'c', 's', '.', 'e', 'd', 'i', 't', 'o', 'r', 's', '.', 'd', 'o', 'c', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'h', 'e', 'm', 'e', 'm', 'a', 'n', 'a', 'g', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 'h', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', ...
# ['[', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'f', 'o', 'l', 'd', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 't', 's', '.', 'p', 'r', 'i', 'v', '.', 'c', 't', 's', 's', 'h', 'i', 'm', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'y', 'o', 'u', 't', 'u', 'b', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'c', 'a', 'm', 'e', 'r', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'e', 'r', 'v', 'i', 'c', 'e', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 's', 'y', 'n', 'e', 'r', 'g', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'l', 'a', 'u', 'n', 'c', 'h', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'm', 'e', 'd', 'i', 'a', 'c', 'e', 'n', 't', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 't', 'e', 'l', 'e', 'p', 'h', 'o', 'n', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'g', 'o', 'o', 'g', 'l', 'e', 'q', 'u', 'i', 'c', 'k', 's', 'e', 'a', 'r', 'c', 'h', 'b', 'o', 'x', "'", ',', ' ', "'", 'n', 'e', 't', '.', 'b', 'i', 'g', 'v', 'n', '.', 'k', 'h', 'e', 'o', 'a', 'n', 'n', 'o', 'i', 's', 'e', 'c', 'o', 'd', 'u', 'o', 'c', 't', 'h', 'i', 'e', 'n', 'h', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'c', 'a', 'l', 'e', 'n', 'd', 'a', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'r', 'i', 'd', 'e', 'm', 'o', 'd', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'e', 'a', 'l', 't', 'h', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'd', 'i', 's', 'k', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'h', 'i', 'v', 'i', 'e', 'w', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'z', 'i', 'n', 'g', '.', 'z', 'a', 'l', 'o', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'i', 'a', 'w', 'a', 'r', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'b', 'l', 'u', 'e', 't', 'o', 'o', 't', 'h', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'p', 'r', 'o', 'v', 'i', 'd', 'e', 'r', 's', '.', 'm', 'e', 'd', 'i', 'a', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 't', 'o', 'u', 'c', 'h', 't', 'y', 'p', 'e', '.', 's', 'w', 'i', 'f', 't', 'k', 'e', 'y', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'a', 'p', 'p', 's', '.', 'd', 'o', 'c', 's', '.', 'e', 'd', 'i', 't', 'o', 'r', 's', '.', 'd', 'o', 'c', 's', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 't', 'h', 'e', 'm', 'e', 'm', 'a', 'n', 'a', 'g', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'm', 'i', 'c', '.', 'b', 'l', 'u', 'e', 'z', 'o', 'n', 'e', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'c', 'h', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'h', 'u', 'a', 'w', 'e', 'i', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'h', 's', 'f', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'o', 'n', 'e', 't', 'i', 'm', 'e', 'i', 'n', 'i', 't', 'i', 'a', 'l', 'i', 'z', 'e', 'r', "'", ',', ' ', "'", 'c', 'o', 'm', '.', 'g', 'o', 'o', 'g', 'l', 'e', '.', 'a', 'n', 'd', 'r', 'o', 'i', 'd', '.', 'e', 'x', 't', '.', 's', 'h', 'a', 'r', 'e', 'd', ...

# %%
cols_exclude_devices = set(df.columns) - set(['hw_device_id', 'installed_packages', 'system_packages', 'list_of_wifi', 'ringtone'])
for _, row in devices_latest.iterrows():
    nd = devices.createDocument({
        '_key': row['hw_device_id'],
        'installed_packages': [x.strip() for x in row['installed_packages'].split(',')] if type(row['installed_packages']) is not float else 'nan',
        'system_packages': [x.strip() for x in row['system_packages'].split(',')] if type(row['system_packages']) is not float else 'nan',
        'list_of_wifi': [k.strip().replace('"', '') for k in row['list_of_wifi'].split(',')] if type(row['list_of_wifi']) is not float else 'nan',
        'ringtone': [k.strip() for k in row['ringtone'].split(',')] if type(row['ringtone']) is not float else 'nan'
    })
    for c in cols_exclude_devices:
        nd[c] = str(row[c])
    nd.save()
# Out:
# ===
# Unable to establish connection, perhaps arango is not running.
# ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-146-a82e5fd68aa4> in <module>
#      10     for c in cols_exclude_devices:
#      11         nd[c] = str(row[c])
# ---> 12     nd.save()
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/pyArango/document.py in save(self, waitForSync, **docArgs)
#     254         It will only trigger a saving of the document if it has been modified since the last save. If you want to force the saving you can use forceSave()"""
#     255         payload = self._store.getStore()
# --> 256         self._save(payload, waitForSync = False, **docArgs)
#     257
#     258     def _save(self, payload, waitForSync = False, **docArgs):
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/pyArango/document.py in _save(self, payload, waitForSync, **docArgs)
#     274                     payload["_key"] = self._key
#     275                 payload = json.dumps(payload, default=str)
# --> 276                 r = self.connection.session.post(self.collection.getDocumentsURL(), params = params, data = payload)
#     277                 update = False
#     278                 data = r.json()
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/pyArango/connection.py in __call__(self, *args, **kwargs)
#      50
#      51             try:
# ---> 52                 ret = self.fct(*args, **kwargs)
#      53             except:
#      54                 print ("===\nUnable to establish connection, perhaps arango is not running.\n===")
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     576         """
#     577
# --> 578         return self.request('POST', url, data=data, json=json, **kwargs)
#     579
#     580     def put(self, url, data=None, **kwargs):
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     390             conn.request_chunked(method, url, **httplib_request_kw)
#     391         else:
# --> 392             conn.request(method, url, **httplib_request_kw)
#     393
#     394         # Reset the timeout for the recv() on the socket
#
# ~/miniconda3/envs/vng/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1253                 encode_chunked=False):
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#    1257     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/miniconda3/envs/vng/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1299             # default charset of iso-8859-1.
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#    1303     def getresponse(self):
#
# ~/miniconda3/envs/vng/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1248         else:
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#    1252     def request(self, method, url, body=None, headers={}, *,
#
# ~/miniconda3/envs/vng/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1008         msg = b"\r\n".join(self._buffer)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#    1012         if message_body is not None:
#
# ~/miniconda3/envs/vng/lib/python3.8/http/client.py in send(self, data)
#     948         if self.sock is None:
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#     952                 raise NotConnected()
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     185
#     186     def connect(self):
# --> 187         conn = self._new_conn()
#     188         self._prepare_conn(conn)
#     189
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     157
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~/miniconda3/envs/vng/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59     family = allowed_gai_family()
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#      63         sock = None
#
# ~/miniconda3/envs/vng/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
# --> 920         addrlist.append((_intenum_converter(af, AddressFamily),
#     921                          _intenum_converter(socktype, SocketKind),
#     922                          proto, canonname, sa))
#
# ~/miniconda3/envs/vng/lib/python3.8/socket.py in _intenum_converter(value, enum_klass)
#     101     """
#     102     try:
# --> 103         return enum_klass(value)
#     104     except ValueError:
#     105         return value
#
# ~/miniconda3/envs/vng/lib/python3.8/enum.py in __call__(cls, value, names, module, qualname, type, start)
#     307         """
#     308         if names is None:  # simple value lookup
# --> 309             return cls.__new__(cls, value)
#     310         # otherwise, functional API: we're creating a new Enum type
#     311         return cls._create_(value, names, module=module, qualname=qualname, type=type, start=start)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Add users - devices

# %%
cols_exclude_users_devices = set(df.columns) - set(['userId', 'hw_device_id', 'installed_packages', 'system_packages'])
for _, row in df.iterrows():
    ud = user_device.createDocument({
        '_from': 'users/' + str(row['userId']),
        '_to': 'devices/' + str(row['hw_device_id'])
    })
    for c in cols_exclude_users_devices:
        ud[c] = str(row[c])
    ud.save()

# %% [markdown]
# ## Devices model

# %%
unique_device_model = df['hw_device_model'].unique()
inserted = []
for uq in unique_device_model:
    formatted = '_'.join(x for x in uq.split(' '))
    if formatted not in inserted:
        inserted.append(formatted)
        device_model.createDocument({
            '_key': formatted
        }).save()

# %% [markdown]
# ## Device - DeviceModel

# %%
for _, row in df.iterrows():
    formatted_device_model = '_'.join(x for x in row['hw_device_model'].split(' '))
    new_ddm = device_deviceModel.createDocument({
        '_from': 'devices/' + str(row['hw_device_id']),
        '_to': 'device_model/' + formatted_device_model,
        'timestamp': str(row['timestamp']),
        'userId': str(row['userId'])
    })
    new_ddm.save()
