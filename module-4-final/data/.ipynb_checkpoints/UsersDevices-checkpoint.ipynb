# %% [markdown]
# # Preprocess Data

# %%
import pandas as pd
import json
from tqdm import tqdm

# %% [markdown]
# ## Device Profile

# %%
android_df = pd.read_csv('raw/dataTest_device_profile_android.csv')
ios_df = pd.read_csv('raw/dataTest_device_profile.csv')
joint_df = pd.concat([android_df, ios_df])
joint_df['params'] = joint_df['params'].apply(lambda x: json.loads(x))
joint_df.head()
# Out:
#     timestamp           userId  \
# 0  1596244856  170425000002238
# 1  1596244830  191113586003363
# 2  1596244888  200413000001404
# 3  1596244831  200428000037320
# 4  1596244849  190309000002524
#
#                                               params
# 0  {'hw_released': 'Tue Jul 07 08:50:39 GMT+07:00...
# 1  {'hw_released': 'Thu Jul 02 12:19:14 GMT+07:00...
# 2  {'hw_released': 'Thu Dec 07 11:24:05 GMT+07:00...
# 3  {'hw_released': 'Wed Apr 22 07:53:33 GMT+07:00...
# 4  {'hw_released': 'Thu Mar 12 12:05:05 GMT+07:00...

# %%
formatted = pd.json_normalize(joint_df['params'])

# %%
joint_df.reset_index(drop=True, inplace=True)

formatted.reset_index(drop=True, inplace=True)

# %%
new_df = pd.concat([joint_df[['timestamp', 'userId']], formatted], axis=1)
new_df.drop_duplicates(inplace=True)
new_df.head()
# Out:
#     timestamp           userId                         hw_released  \
# 0  1596244856  170425000002238  Tue Jul 07 08:50:39 GMT+07:00 2020
# 1  1596244830  191113586003363  Thu Jul 02 12:19:14 GMT+07:00 2020
# 2  1596244888  200413000001404  Thu Dec 07 11:24:05 GMT+07:00 2017
# 3  1596244831  200428000037320  Wed Apr 22 07:53:33 GMT+07:00 2020
# 4  1596244849  190309000002524  Thu Mar 12 12:05:05 GMT+07:00 2020
#
#        hw_device_id battery_voltage    hw_board        hw_cpu_name  \
# 0  f21ebb2f9064b16e         4091 mV  exynos9810         exynos9810
# 1  13cf342d200936c8         4260 mV        AGS2             hi6250
# 2  b41f717314855504         3508 mV     SC9830I             sc8830
# 3  8d36707898c6955d         3877 mV  exynos9810  samsungexynos9810
# 4  af1934dafd8aba01         3644 mV      mt6757             mt6757
#
#   hw_screen_aspect_ratio hw_screen_class battery_type  ... sim_operator_name  \
# 0                      2          Normal       Li-ion  ...               NaN
# 1                      1           Large      Li-poly  ...               NaN
# 2                      1          Normal       Li-ion  ...                vn
# 3                      2          Normal       Li-ion  ...               NaN
# 4                      1          Normal       Li-ion  ...               NaN
#
#   hw_camera_front_optical_stabilization hw_camera_front_resolution  \
# 0                                   NaN                        NaN
# 1                                   NaN                        NaN
# 2                                    NO                       4 MP
# 3                                   NaN                        NaN
# 4                                    NO                      15 MP
#
#   hw_camera_back_resolution sim_operator  \
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                      7 MP        45204
# 3                       NaN          NaN
# 4                     12 MP          NaN
#
#   hw_camera_back_longest_exposure_value  \
# 0                                   NaN
# 1                                   NaN
# 2
# 3                                   NaN
# 4
#
#                  hw_camera_back_supported_resolution hw_capacity_force_touch  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2  3264x2448\n2592x1936\n2048x1536\n1600x1200\n12...                     NaN
# 3                                                NaN                     NaN
# 4  4128x3096\n4128x2320\n3264x1836\n3264x2448\n30...                     NaN
#
#   os_multitasking cellular_capabilities
# 0             NaN                   NaN
# 1             NaN                   NaN
# 2             NaN                   NaN
# 3             NaN                   NaN
# 4             NaN                   NaN
#
# [5 rows x 79 columns]

# %%
required_cols = ['timestamp', 'userId', 'hw_released', 'hw_board', 'hw_screen_class', 'hw_cpu_supported_abis', 'hw_device_id', 'hw_cpu_name',
       'hw_screen_aspect_ratio', 'hw_screen_pixel_density', 'system_packages', 'battery_type', ''
       'network_wifi_mac_address', 'hw_screen_resolution', 'os_version',
       'hw_device_manufacturer', 'hw_cpu_speed', 'hw_device_model',
       'hw_screen_refresh_rate', 'os_name', 'os_root_access',
       'hw_cpu_supported_64_bit_abis', 'user_agent', 'hw_device_string',
       'os_version_name', 'hw_cpu_core_count', 'hw_cpu_supported_32_bit_abis',
       'hw_cpu_processor', 'hw_cpu_manufacturer', 'hw_screen_size',
       'hw_bluetooth_address', 'installed_packages', 'hw_ram_total',
       'hw_cpu_min_speed', 'hw_storage_total', 'list_of_wifi',
       'hw_camera_front_max_photo_resolution',
       'hw_camera_back_max_video_resolution', 'ringtone',
       'hw_camera_number_camera', 'hw_camera_back_max_photo_resolution',
       'hw_camera_front_max_video_resolution']

# %%
df = new_df[required_cols]

# %%
df.duplicated().value_counts()
# Out:
# False    495535
# True         39
# dtype: int64

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Device Transaction

# %%
app_id = pd.read_excel('raw/AppID Merchant.xlsx')
app_id = app_id[['Merchant', 'App ID']]
app_id.columns = ['merchant', 'appid']

# format to snake case
# app_id['merchant'] = app_id['merchant'].apply(lambda x: '_'.join([c for c in x.replace(',', '').lower().split(' ') if c.isalnum()]))
app_id.head()
# Out:
#            merchant  appid
# 0          App Test      3
# 1          App Test    742
# 2          App Test  10033
# 3          App Test  10034
# 4  Business Service     26

# %%
columns = ['deviceID', 'transID', 'transType', 'appid', 'pmcID', 'amount', 'userID', 'osVer', 'deviceModel', 'userIP', 'reqDate', 'longitude', 'latitude', 'campaignID', 'type_transaction']
tpe = pd.read_csv('raw/tpe_device_score.csv', names=columns)
tpe.head()
# Out:
#            deviceID          transID  transType  appid  pmcID   amount  \
# 0  000195863904dc8a  200808000071150          1    454     39  2000000
# 1  000195863904dc8a  200808000089357          1    454     39  2000000
# 2  000195863904dc8a  200809000160928          1    454     39  2000000
# 3  000195863904dc8a  200822000188187          1    454     39  2000000
# 4  000195863904dc8a  200822000271777          1    454     39  2000000
#
#             userID           osVer       deviceModel          userIP  \
# 0  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
# 1  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
# 2  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
# 3  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
# 4  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
#
#                    reqDate   longitude   latitude  campaignID type_transaction
# 0  2020-08-08 08:51:08.856  105.952103  10.223810           0          payment
# 1  2020-08-08 09:47:11.279  105.952107  10.223811           0          payment
# 2  2020-08-09 14:43:45.359  105.952099  10.223812           0          payment
# 3  2020-08-22 14:33:30.566  105.952106  10.223818           0          payment
# 4  2020-08-22 20:30:36.476  105.952090  10.223808           0          payment

# %%
joined_df = tpe.join(app_id.set_index('appid'), how='inner', on='appid')
joined_df.head()
# Out:
#            deviceID          transID  transType  appid  pmcID   amount  \
# 0  000195863904dc8a  200808000071150          1    454     39  2000000
# 1  000195863904dc8a  200808000089357          1    454     39  2000000
# 2  000195863904dc8a  200809000160928          1    454     39  2000000
# 3  000195863904dc8a  200822000188187          1    454     39  2000000
# 4  000195863904dc8a  200822000271777          1    454     39  2000000
#
#             userID           osVer       deviceModel          userIP  \
# 0  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
# 1  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
# 2  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
# 3  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
# 4  200119000040347  Android 28 (9)  Samsung SM-J730G  125.214.48.174
#
#                    reqDate   longitude   latitude  campaignID  \
# 0  2020-08-08 08:51:08.856  105.952103  10.223810           0
# 1  2020-08-08 09:47:11.279  105.952107  10.223811           0
# 2  2020-08-09 14:43:45.359  105.952099  10.223812           0
# 3  2020-08-22 14:33:30.566  105.952106  10.223818           0
# 4  2020-08-22 20:30:36.476  105.952090  10.223808           0
#
#   type_transaction        merchant
# 0          payment  Money Transfer
# 1          payment  Money Transfer
# 2          payment  Money Transfer
# 3          payment  Money Transfer
# 4          payment  Money Transfer

# %%
# Check nan
joined_df.isna().count()
# Out:
# deviceID            2164765
# transID             2164765
# transType           2164765
# appid               2164765
# pmcID               2164765
# amount              2164765
# userID              2164765
# osVer               2164765
# deviceModel         2164765
# userIP              2164765
# reqDate             2164765
# longitude           2164765
# latitude            2164765
# campaignID          2164765
# type_transaction    2164765
# merchant            2164765
# dtype: int64

# %%
# Check nan
joined_df.isna().count()
# Out:
# deviceID            2164765
# transID             2164765
# transType           2164765
# appid               2164765
# pmcID               2164765
# amount              2164765
# userID              2164765
# osVer               2164765
# deviceModel         2164765
# userIP              2164765
# reqDate             2164765
# longitude           2164765
# latitude            2164765
# campaignID          2164765
# type_transaction    2164765
# merchant            2164765
# dtype: int64

# %%
joined_df[joined_df['deviceID'] == '000195863904dc8a'].groupby(['userID', 'merchant'])['appid'].count()
# Out:
# userID           merchant
# 200119000040347  Digital Goods      2
#                  Money Transfer    16
# Name: appid, dtype: int64

# %% [markdown]
# # Insert data into ArangoDB

# %% [markdown]
# ## Add users

# %%
unique_dp_users = df['userId'].unique()
unique_tpe_users = joined_df['userID'].unique()
len(unique_dp_users), len(unique_tpe_users)
# Out:
# (409836, 236570)

# %%
# In tpe but not in dp
len(set(unique_tpe_users) - set(unique_dp_users))
# Out:
# 1549

# %%
unique_total_users = list(set(unique_dp_users) | set(unique_tpe_users))

# %%
user_list = []
for u in tqdm(unique_total_users):
    user_list.append({
        '_key': str(u)
    })
# Out:
# 100%|██████████| 411385/411385 [00:00<00:00, 650456.01it/s]

# %%
with open('json/users.json', 'w') as f:
    json.dump(user_list, f)

# %%
# Convert json to jsonl
# !jq -c ".[]" json/users.json > jsonl/users.jsonl

# %%
# import to arangodbarangoimport --create-collection true --collection users --type jsonl --file "jsonl/users.jsonl" --progress true --threads 16
# !arangoimport --server.password=ngph  --create-collection true --collection users --type jsonl --file "jsonl/users.jsonl" --progress true --threads 16

# %% [markdown]
# ## Add latest devices info

# %%
devices_latest = df[df.groupby(['hw_device_id'])['timestamp'].transform(max) == df['timestamp']]

# %%
def format_packages(x):
    return x.split(', ') if type(x) is not float else 'nan'

# %%
def format_list_of_wifi(x):
    if type(x) is not float and x != '':
        return x.replace('"', '').split(', ')
    else:
        return 'nan'

# %%
def format_ringtone(x):
    return x.strip(',').split(',') if type(x) is not float else 'nan'

# %%
def create_device_info_doc(row, cols_exclude_devices):
    e = {
            '_id': row['hw_device_id'],
            '_key': row['hw_device_id'],
            'installed_packages': format_packages(row['installed_packages']),
            'system_packages': format_packages(row['system_packages']),
            'list_of_wifi': format_list_of_wifi(row['list_of_wifi']),
            'ringtone': format_ringtone(row['ringtone'])
        }
    for c in cols_exclude_devices:
        e[c] = str(row[c])
    return e

# %%
device_info = []
cols_exclude_devices = set(df.columns) - set(['hw_device_id', 'installed_packages', 'system_packages', 'list_of_wifi', 'ringtone'])
devices_latest['arangoCode'] = devices_latest.apply(lambda x: create_device_info_doc(x, cols_exclude_devices) , 1)
# Out:
# <ipython-input-63-4d0cbebc1339>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   devices_latest['arangoCode'] = devices_latest.apply(lambda x: create_device_info_edge(x, cols_exclude_devices) , 1)

# %%
devices_latest_list = devices_latest['arangoCode'].tolist()

# %%
with open('json/devices.json', 'w') as f:
    json.dump(devices_latest_list, f)

# %%
# Convert json to jsonl
# !jq -c ".[]" json/devices.json > jsonl/devices.jsonl

# %%
# !arangoimport --server.password=ngph  --create-collection true --collection devices --type jsonl --file "jsonl/devices.jsonl" --progress true --threads 16
# Out:
# Connected to ArangoDB 'http+tcp://127.0.0.1:8529, version: 3.7.2, database: '_system', username: 'root'
# ----------------------------------------
# database:               _system
# collection:             devices
# create:                 yes
# create database:        no
# source filename:        jsonl/devices.jsonl
# file type:              jsonl
# threads:                16
# connect timeout:        5
# request timeout:        1200
# ----------------------------------------
# Starting JSON import...
# 2020-09-21T15:00:32Z [12144] INFO [9ddf3] processed 34175981 bytes (3%) of input file
# 2020-09-21T15:00:34Z [12144] INFO [9ddf3] processed 68319195 bytes (6%) of input file
# 2020-09-21T15:00:35Z [12144] INFO [9ddf3] processed 102495176 bytes (9%) of input file
# 2020-09-21T15:00:37Z [12144] INFO [9ddf3] processed 136638390 bytes (12%) of input file
# 2020-09-21T15:00:38Z [12144] INFO [9ddf3] processed 170814371 bytes (15%) of input file
# 2020-09-21T15:00:40Z [12144] INFO [9ddf3] processed 204957585 bytes (18%) of input file
# 2020-09-21T15:00:41Z [12144] INFO [9ddf3] processed 239133566 bytes (21%) of input file
# 2020-09-21T15:00:42Z [12144] INFO [9ddf3] processed 273276780 bytes (24%) of input file
# 2020-09-21T15:00:44Z [12144] INFO [9ddf3] processed 307452761 bytes (27%) of input file
# 2020-09-21T15:00:45Z [12144] INFO [9ddf3] processed 341595975 bytes (30%) of input file
# 2020-09-21T15:00:46Z [12144] INFO [9ddf3] processed 375771956 bytes (33%) of input file
# 2020-09-21T15:00:48Z [12144] INFO [9ddf3] processed 409915170 bytes (36%) of input file
# 2020-09-21T15:00:49Z [12144] INFO [9ddf3] processed 444091151 bytes (39%) of input file
# 2020-09-21T15:00:50Z [12144] INFO [9ddf3] processed 478234365 bytes (42%) of input file
# 2020-09-21T15:00:51Z [12144] INFO [9ddf3] processed 512410346 bytes (45%) of input file
# 2020-09-21T15:00:52Z [12144] INFO [9ddf3] processed 546553560 bytes (48%) of input file
# 2020-09-21T15:00:53Z [12144] INFO [9ddf3] processed 580729541 bytes (51%) of input file
# 2020-09-21T15:00:53Z [12144] INFO [9ddf3] processed 614872755 bytes (54%) of input file
# 2020-09-21T15:00:54Z [12144] INFO [9ddf3] processed 649048736 bytes (57%) of input file
# 2020-09-21T15:00:55Z [12144] INFO [9ddf3] processed 683191950 bytes (60%) of input file
# 2020-09-21T15:00:56Z [12144] INFO [9ddf3] processed 717367931 bytes (63%) of input file
# 2020-09-21T15:00:57Z [12144] INFO [9ddf3] processed 751511145 bytes (66%) of input file
# 2020-09-21T15:00:58Z [12144] INFO [9ddf3] processed 785687126 bytes (69%) of input file
# 2020-09-21T15:00:59Z [12144] INFO [9ddf3] processed 819830340 bytes (72%) of input file
# 2020-09-21T15:01:00Z [12144] INFO [9ddf3] processed 854006321 bytes (75%) of input file
# 2020-09-21T15:01:00Z [12144] INFO [9ddf3] processed 888149535 bytes (78%) of input file
# 2020-09-21T15:01:01Z [12144] INFO [9ddf3] processed 922292749 bytes (81%) of input file
# 2020-09-21T15:01:02Z [12144] INFO [9ddf3] processed 956468730 bytes (84%) of input file
# 2020-09-21T15:01:02Z [12144] INFO [9ddf3] processed 990611944 bytes (87%) of input file
# 2020-09-21T15:01:03Z [12144] INFO [9ddf3] processed 1024787925 bytes (90%) of input file
# 2020-09-21T15:01:03Z [12144] INFO [9ddf3] processed 1058931139 bytes (93%) of input file
# 2020-09-21T15:01:04Z [12144] INFO [9ddf3] processed 1093107120 bytes (96%) of input file
# 2020-09-21T15:01:05Z [12144] INFO [9ddf3] processed 1127250334 bytes (99%) of input file
#
# created:          407741
# warnings/errors:  0
# updated/replaced: 0
# ignored:          0

# %% [markdown]
# ## Add users - devices

# %%
def create_user_device_edge(row, cols_exclude_users_devices):
    e = {
            '_key': f"{str(row['userId']).strip()}_{str(row['hw_device_id'])}_{row['timestamp']}",
            '_from': 'users/' + str(row['userId']).strip(),
            '_to': 'devices/' + str(row['hw_device_id']).strip(),
            'type': 'user_use_device'
        }
    for c in cols_exclude_users_devices:
        e[c] = str(row[c]).strip()
    return e

# %%
cols_exclude_users_devices = set(df.columns) - set(['userId', 'hw_device_id', 'installed_packages', 'system_packages', 'list_of_wifi', 'ringtone'])
df['arangoCode'] = df.apply(lambda row: create_user_device_edge(row, cols_exclude_users_devices), 1)

# %%
user_devices_list = df['arangoCode'].tolist()

# %%
with open('json/users_use_devices.json', 'w') as f:
    json.dump(user_devices_list, f)

# %%
# Convert json to jsonl
# !jq -c ".[]" json/users_use_devices.json > jsonl/users_use_devices.jsonl

# %%
# !arangoimport --server.password=ngph --create-collection true --create-collection-type edge --collection users_devices  --type jsonl --file "jsonl/users_use_devices.jsonl" --progress true --threads 16
# Out:
# Connected to ArangoDB 'http+tcp://127.0.0.1:8529, version: 3.7.2, database: '_system', username: 'root'
# ----------------------------------------
# database:               _system
# collection:             users_devices
# create:                 yes
# create database:        no
# source filename:        jsonl/users_use_devices.jsonl
# file type:              jsonl
# threads:                16
# connect timeout:        5
# request timeout:        1200
# ----------------------------------------
# Starting JSON import...
# 2020-09-21T15:10:59Z [12716] INFO [9ddf3] processed 21593453 bytes (3%) of input file
# 2020-09-21T15:11:00Z [12716] INFO [9ddf3] processed 43186906 bytes (6%) of input file
# 2020-09-21T15:11:01Z [12716] INFO [9ddf3] processed 64747592 bytes (9%) of input file
# 2020-09-21T15:11:02Z [12716] INFO [9ddf3] processed 86341045 bytes (12%) of input file
# 2020-09-21T15:11:03Z [12716] INFO [9ddf3] processed 107934498 bytes (15%) of input file
# 2020-09-21T15:11:04Z [12716] INFO [9ddf3] processed 129495184 bytes (18%) of input file
# 2020-09-21T15:11:05Z [12716] INFO [9ddf3] processed 151088637 bytes (21%) of input file
# 2020-09-21T15:11:06Z [12716] INFO [9ddf3] processed 172649323 bytes (24%) of input file
# 2020-09-21T15:11:06Z [12716] INFO [9ddf3] processed 194242776 bytes (27%) of input file
# 2020-09-21T15:11:07Z [12716] INFO [9ddf3] processed 215836229 bytes (30%) of input file
# 2020-09-21T15:11:08Z [12716] INFO [9ddf3] processed 237396915 bytes (33%) of input file
# 2020-09-21T15:11:09Z [12716] INFO [9ddf3] processed 258990368 bytes (36%) of input file
# 2020-09-21T15:11:10Z [12716] INFO [9ddf3] processed 280583821 bytes (39%) of input file
# 2020-09-21T15:11:10Z [12716] INFO [9ddf3] processed 302144507 bytes (42%) of input file
# 2020-09-21T15:11:11Z [12716] INFO [9ddf3] processed 323737960 bytes (45%) of input file
# 2020-09-21T15:11:12Z [12716] INFO [9ddf3] processed 345298646 bytes (48%) of input file
# 2020-09-21T15:11:12Z [12716] INFO [9ddf3] processed 366892099 bytes (51%) of input file
# 2020-09-21T15:11:13Z [12716] INFO [9ddf3] processed 388485552 bytes (54%) of input file
# 2020-09-21T15:11:14Z [12716] INFO [9ddf3] processed 410046238 bytes (57%) of input file
# 2020-09-21T15:11:14Z [12716] INFO [9ddf3] processed 431639691 bytes (60%) of input file
# 2020-09-21T15:11:15Z [12716] INFO [9ddf3] processed 453233144 bytes (63%) of input file
# 2020-09-21T15:11:16Z [12716] INFO [9ddf3] processed 474793830 bytes (66%) of input file
# 2020-09-21T15:11:16Z [12716] INFO [9ddf3] processed 496387283 bytes (69%) of input file
# 2020-09-21T15:11:17Z [12716] INFO [9ddf3] processed 517947969 bytes (72%) of input file
# 2020-09-21T15:11:18Z [12716] INFO [9ddf3] processed 539541422 bytes (75%) of input file
# 2020-09-21T15:11:18Z [12716] INFO [9ddf3] processed 561134875 bytes (78%) of input file
# 2020-09-21T15:11:19Z [12716] INFO [9ddf3] processed 582695561 bytes (81%) of input file
# 2020-09-21T15:11:19Z [12716] INFO [9ddf3] processed 604289014 bytes (84%) of input file
# 2020-09-21T15:11:20Z [12716] INFO [9ddf3] processed 625882467 bytes (87%) of input file
# 2020-09-21T15:11:20Z [12716] INFO [9ddf3] processed 647443153 bytes (90%) of input file
# 2020-09-21T15:11:21Z [12716] INFO [9ddf3] processed 669036606 bytes (93%) of input file
# 2020-09-21T15:11:21Z [12716] INFO [9ddf3] processed 690597292 bytes (96%) of input file
# 2020-09-21T15:11:22Z [12716] INFO [9ddf3] processed 712190745 bytes (99%) of input file
#
# created:          495535
# warnings/errors:  0
# updated/replaced: 0
# ignored:          0

# %% [markdown]
# ## Devices model

# %%
unique_device_model = df['hw_device_model'].apply(lambda x: x.lower().replace('-', '_').replace(' ', '_')).unique()
dm_list = []
for uq in unique_device_model:
    dm_list.append({
        '_key': uq
    })

# %%
with open('json/device_model.json', 'w') as f:
    json.dump(dm_list, f)

# %%
# Convert json to jsonl
# !jq -c ".[]" json/device_model.json > jsonl/device_model.jsonl

# %%
# !arangoimport --server.password=ngph --collection device_model --create-collection true --type jsonl --file "jsonl/device_model.jsonl" --progress true --threads 16
# Out:
# Connected to ArangoDB 'http+tcp://127.0.0.1:8529, version: 3.7.2, database: '_system', username: 'root'
# ----------------------------------------
# database:               _system
# collection:             device_model
# create:                 yes
# create database:        no
# source filename:        jsonl/device_model.jsonl
# file type:              jsonl
# threads:                16
# connect timeout:        5
# request timeout:        1200
# ----------------------------------------
# Starting JSON import...
# 2020-09-21T14:42:03Z [10700] INFO [9ddf3] processed 24309 bytes (3%) of input file
#
# created:          1200
# warnings/errors:  0
# updated/replaced: 0
# ignored:          0

# %% [markdown]
# ## Device - DeviceModel

# %%
ddm_df = df.groupby(['hw_device_id', 'hw_device_model'], as_index=False).timestamp.max()
ddm_df.head()
# Out:
#                            hw_device_id hw_device_model   timestamp
# 0  000081FB-CAE0-4DBE-8983-D54759750014       iPhone 6s  1596520549
# 1  0000B1B7-9075-487E-B363-0FF4AE8FF05C   iPhone 7 Plus  1598881038
# 2  0000B625-66C9-4B23-8509-67B50D0737AE       iPhone 11  1597714312
# 3  000103C2-C989-435C-8E5E-15A0D9E03199       iPhone 6s  1596728757
# 4  00017D00-6F9E-4956-AB4C-FEA04F5115F1        iPhone 6  1598836556

# %%
def create_edge(row):
    return {
            '_from': 'devices/' + str(row['hw_device_id']),
            '_to': 'device_model/' + str(row['hw_device_model'].lower().replace('-', '_').replace(' ', '_')),
            'timestamp': str(row['timestamp'])
    }

# %%
ddm_df['arangoCode'] = ddm_df.apply(create_edge,1)

# %%
ddm_list = ddm_df['arangoCode'].tolist()

# %%
with open('json/device_devicemodel.json', 'w') as f:
    json.dump(ddm_list, f)

# %%
# Convert json to jsonl
# !jq -c ".[]" json/device_devicemodel.json > jsonl/device_devicemodel.jsonl

# %%
# !arangoimport --server.password=ngph --collection device_devicemodel --create-collection true --create-collection-type edge --type jsonl --file "jsonl/device_devicemodel.jsonl" --progress true --threads 16
# Out:
# Connected to ArangoDB 'http+tcp://127.0.0.1:8529, version: 3.7.2, database: '_system', username: 'root'
# ----------------------------------------
# database:               _system
# collection:             device_devicemodel
# create:                 yes
# create database:        no
# source filename:        jsonl/device_devicemodel.jsonl
# file type:              jsonl
# threads:                16
# connect timeout:        5
# request timeout:        1200
# ----------------------------------------
# Starting JSON import...
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 1408981 bytes (3%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 2817962 bytes (6%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 4194176 bytes (9%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 5603157 bytes (12%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 6979371 bytes (15%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 8388352 bytes (18%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 9764566 bytes (21%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 11173547 bytes (24%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 12549761 bytes (27%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 13958742 bytes (30%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 15334956 bytes (33%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 16743937 bytes (36%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 18120151 bytes (39%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 19529132 bytes (42%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 20905346 bytes (45%) of input file
# 2020-09-21T14:44:19Z [10943] INFO [9ddf3] processed 22314327 bytes (48%) of input file
# 2020-09-21T14:44:20Z [10943] INFO [9ddf3] processed 23690541 bytes (51%) of input file
# 2020-09-21T14:44:20Z [10943] INFO [9ddf3] processed 25099522 bytes (54%) of input file
# 2020-09-21T14:44:20Z [10943] INFO [9ddf3] processed 26475736 bytes (57%) of input file
# 2020-09-21T14:44:20Z [10943] INFO [9ddf3] processed 27884717 bytes (60%) of input file
# 2020-09-21T14:44:21Z [10943] INFO [9ddf3] processed 29260931 bytes (63%) of input file
# 2020-09-21T14:44:21Z [10943] INFO [9ddf3] processed 30669912 bytes (66%) of input file
# 2020-09-21T14:44:21Z [10943] INFO [9ddf3] processed 32046126 bytes (69%) of input file
# 2020-09-21T14:44:21Z [10943] INFO [9ddf3] processed 33455107 bytes (72%) of input file
# 2020-09-21T14:44:21Z [10943] INFO [9ddf3] processed 34831321 bytes (75%) of input file
# 2020-09-21T14:44:21Z [10943] INFO [9ddf3] processed 36240302 bytes (78%) of input file
# 2020-09-21T14:44:21Z [10943] INFO [9ddf3] processed 37616516 bytes (81%) of input file
# 2020-09-21T14:44:22Z [10943] INFO [9ddf3] processed 39025497 bytes (84%) of input file
# 2020-09-21T14:44:22Z [10943] INFO [9ddf3] processed 40401711 bytes (87%) of input file
# 2020-09-21T14:44:22Z [10943] INFO [9ddf3] processed 41810692 bytes (90%) of input file
# 2020-09-21T14:44:22Z [10943] INFO [9ddf3] processed 43186906 bytes (93%) of input file
# 2020-09-21T14:44:22Z [10943] INFO [9ddf3] processed 44595887 bytes (96%) of input file
# 2020-09-21T14:44:22Z [10943] INFO [9ddf3] processed 45972101 bytes (99%) of input file
#
# created:          407900
# warnings/errors:  0
# updated/replaced: 0
# ignored:          0

# %% [markdown]
# ## Device Merchant TPE Activity

# %%
def create_user_device_tpe_edge(row, cols_excluded):
    new_dm = {
            '_key': str(row['transID']),
            '_to': 'devices/' + str(row['deviceID']),
            '_from': 'users/' + str(row['userID']),
            'type': 'transaction'
        }
    for c in cols_excluded:
        new_dm[c] = str(row[c])
    return new_dm

# %%
cols_excluded = set(joined_df.columns) - set(['deviceID', 'userID'])
joined_df['arangoCode'] = joined_df.apply(lambda row: create_user_device_tpe_edge(row, cols_excluded), 1)

# %%
tpe = joined_df['arangoCode'].tolist()

# %%
with open('json/tpe.json', 'w') as f:
    json.dump(tpe, f)

# %%
# Convert json to jsonl
# !jq -c ".[]" json/tpe.json > jsonl/tpe.jsonl

# %%
# !arangoimport --server.password=ngph --collection users_devices --type jsonl --file "jsonl/tpe.jsonl" --progress true --threads 16
# Out:
# Connected to ArangoDB 'http+tcp://127.0.0.1:8529, version: 3.7.2, database: '_system', username: 'root'
# ----------------------------------------
# database:               _system
# collection:             users_devices
# create:                 no
# create database:        no
# source filename:        jsonl/tpe.jsonl
# file type:              jsonl
# threads:                16
# connect timeout:        5
# request timeout:        1200
# ----------------------------------------
# Starting JSON import...
# 2020-09-21T15:48:33Z [15949] INFO [9ddf3] processed 28671125 bytes (3%) of input file
# 2020-09-21T15:48:35Z [15949] INFO [9ddf3] processed 57309483 bytes (6%) of input file
# 2020-09-21T15:48:37Z [15949] INFO [9ddf3] processed 85947841 bytes (9%) of input file
# 2020-09-21T15:48:39Z [15949] INFO [9ddf3] processed 114586199 bytes (12%) of input file
# 2020-09-21T15:48:41Z [15949] INFO [9ddf3] processed 143257324 bytes (15%) of input file
# 2020-09-21T15:48:44Z [15949] INFO [9ddf3] processed 171895682 bytes (18%) of input file
# 2020-09-21T15:48:46Z [15949] INFO [9ddf3] processed 200534040 bytes (21%) of input file
# 2020-09-21T15:48:48Z [15949] INFO [9ddf3] processed 229172398 bytes (24%) of input file
# 2020-09-21T15:48:49Z [15949] INFO [9ddf3] processed 257810756 bytes (27%) of input file
# 2020-09-21T15:48:51Z [15949] INFO [9ddf3] processed 286481881 bytes (30%) of input file
# 2020-09-21T15:48:52Z [15949] INFO [9ddf3] processed 315120239 bytes (33%) of input file
# 2020-09-21T15:48:53Z [15949] INFO [9ddf3] processed 343758597 bytes (36%) of input file
# 2020-09-21T15:48:54Z [15949] INFO [9ddf3] processed 372396955 bytes (39%) of input file
# 2020-09-21T15:48:56Z [15949] INFO [9ddf3] processed 401068080 bytes (42%) of input file
# 2020-09-21T15:48:57Z [15949] INFO [9ddf3] processed 429706438 bytes (45%) of input file
# 2020-09-21T15:48:58Z [15949] INFO [9ddf3] processed 458344796 bytes (48%) of input file
# 2020-09-21T15:48:59Z [15949] INFO [9ddf3] processed 486983154 bytes (51%) of input file
# 2020-09-21T15:49:01Z [15949] INFO [9ddf3] processed 515621512 bytes (54%) of input file
# 2020-09-21T15:49:02Z [15949] INFO [9ddf3] processed 544292637 bytes (57%) of input file
# 2020-09-21T15:49:03Z [15949] INFO [9ddf3] processed 572930995 bytes (60%) of input file
# 2020-09-21T15:49:04Z [15949] INFO [9ddf3] processed 601569353 bytes (63%) of input file
# 2020-09-21T15:49:05Z [15949] INFO [9ddf3] processed 630207711 bytes (66%) of input file
# 2020-09-21T15:49:07Z [15949] INFO [9ddf3] processed 658878836 bytes (69%) of input file
# 2020-09-21T15:49:08Z [15949] INFO [9ddf3] processed 687517194 bytes (72%) of input file
# 2020-09-21T15:49:09Z [15949] INFO [9ddf3] processed 716155552 bytes (75%) of input file
# 2020-09-21T15:49:10Z [15949] INFO [9ddf3] processed 744793910 bytes (78%) of input file
# 2020-09-21T15:49:12Z [15949] INFO [9ddf3] processed 773432268 bytes (81%) of input file
# 2020-09-21T15:49:13Z [15949] INFO [9ddf3] processed 802103393 bytes (84%) of input file
# 2020-09-21T15:49:14Z [15949] INFO [9ddf3] processed 830741751 bytes (87%) of input file
# 2020-09-21T15:49:15Z [15949] INFO [9ddf3] processed 859380109 bytes (90%) of input file
# 2020-09-21T15:49:16Z [15949] INFO [9ddf3] processed 888018467 bytes (93%) of input file
# 2020-09-21T15:49:17Z [15949] INFO [9ddf3] processed 916689592 bytes (96%) of input file
# 2020-09-21T15:49:18Z [15949] INFO [9ddf3] processed 945327950 bytes (99%) of input file
#
# created:          2164765
# warnings/errors:  0
# updated/replaced: 0
# ignored:          0

# %% [markdown]
# # Test

# %%
df.head()
# Out:
#     timestamp           userId                         hw_released  \
# 0  1596244856  170425000002238  Tue Jul 07 08:50:39 GMT+07:00 2020
# 1  1596244830  191113586003363  Thu Jul 02 12:19:14 GMT+07:00 2020
# 2  1596244888  200413000001404  Thu Dec 07 11:24:05 GMT+07:00 2017
# 3  1596244831  200428000037320  Wed Apr 22 07:53:33 GMT+07:00 2020
# 4  1596244849  190309000002524  Thu Mar 12 12:05:05 GMT+07:00 2020
#
#        hw_device_id        hw_cpu_name hw_screen_aspect_ratio  \
# 0  f21ebb2f9064b16e         exynos9810                      2
# 1  13cf342d200936c8             hi6250                      1
# 2  b41f717314855504             sc8830                      1
# 3  8d36707898c6955d  samsungexynos9810                      2
# 4  af1934dafd8aba01             mt6757                      1
#
#   hw_screen_pixel_density                                    system_packages  \
# 0                 420 Dpi  com.samsung.android.provider.filterprovider, c...
# 1                 320 Dpi  com.huawei.hifolder, com.android.cts.priv.ctss...
# 2                 320 Dpi  com.monotype.android.font.rosemary, com.sec.an...
# 3                 420 Dpi  com.samsung.android.provider.filterprovider, c...
# 4                 420 Dpi  com.samsung.android.provider.filterprovider, c...
#
#   network_wifi_mac_address hw_screen_resolution  ... hw_ram_total  \
# 0        12:2F:14:33:9D:E7            1080x2400  ...      7,94 GB
# 1        A8:E5:44:0E:BD:BB            1200x1920  ...      2,88 GB
# 2        AC:AF:B9:61:36:C8             720x1280  ...      1,33 GB
# 3        24:18:1D:FE:E3:E0            1080x2220  ...      5,89 GB
# 4        A4:6C:F1:C3:34:4E            1080x1920  ...      3.92 GB
#
#   hw_cpu_min_speed hw_storage_total  \
# 0         455000Hz           118 GB
# 1         480000Hz         25,23 GB
# 2         768000Hz          4,79 GB
# 3         455000Hz           120 GB
# 4         247000Hz         26.75 GB
#
#                                         list_of_wifi  \
# 0
# 1  "Dinh1", "MaiCa", "NhuQuynh", "Support", "Nam ...
# 2  "Xiaomi_70BE_8F41", "COM TAM SONG ANH", "Redmi...
# 3
# 4  "NamCoffee&Milktea", "YÊU MỘT NGƯỜI", "Studio1...
#
#   hw_camera_front_max_photo_resolution hw_camera_back_max_video_resolution  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                            2576x1932                           3264x2448
# 3                                  NaN                                 NaN
# 4                            4608x3456                           4128x3096
#
#                                             ringtone hw_camera_number_camera  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2  Basic Bell,Basic Tone,Beep Once,Beep-Beep,Begi...                       2
# 3                                                NaN                     NaN
# 4                                                NaN                       2
#
#   hw_camera_back_max_photo_resolution hw_camera_front_max_video_resolution
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                           3264x2448                            2576x1932
# 3                                 NaN                                  NaN
# 4                           4128x3096                            4608x3456
#
# [5 rows x 38 columns]

# %%
df.groupby(['userId']).agg({'hw_device_id': 'count'}).sort_values(by="hw_device_id")
# Out:
#                  hw_device_id
# userId
# 160514000003501             1
# 200124000031214             1
# 200124000031205             1
# 200124000031090             1
# 200124000031055             1
# ...                       ...
# 191101679002231            67
# 171106000000266            68
# 190224000013026            86
# 200629000000643            93
# 171025000014202           107
#
# [409836 rows x 1 columns]

# %% [markdown]
# ### Device Connects To Users Count

# %%
df.groupby('hw_device_id').agg({'userId': lambda x: len(set(x))}).sort_values('userId', ascending=False)[:10]
# Out:
#                                       userId
# hw_device_id
# 460968F8-068F-41C8-B130-2F5F7E968C9C      49
# A5AA40DE-35CB-4406-B4E9-B10E497766A0      35
# EDF10704-E7E4-4CC6-BA25-9A30C7720D02      32
# 027894A1-E617-4A74-9035-33E36FE16800      32
# 0CA30A94-6251-4727-8340-9B6BE942AACB      31
# F8E47BD8-EA84-4621-94C8-104B535C3097      21
# 51E7555D-BC41-483A-B627-7FD3A6693E4E      20
# 3C9D6E46-A3C6-456E-BB39-48C0154C7F5A      20
# 3A8BA073-A02B-47E1-81EF-C69A62A879C2      19
# D9E7640D-A830-4CDB-B653-DE1F1F3D2FC6      18

# %% [markdown]
# ### Device connects with many types of merchants

# %%
joined_df.groupby('deviceID').agg({'merchant': lambda x: len(set(x))}).sort_values('merchant')
# Out:
#                                       merchant
# deviceID
# 000081FB-CAE0-4DBE-8983-D54759750014         1
# C16652ED-8950-4035-A4D5-241F48739561         1
# 5CAB69E8-804E-49E5-96C2-72B65AD5D587         1
# C1666B77-C749-4303-9D86-7040AB26AEAC         1
# 5CAB04E3-859C-4A31-98A2-B3BE01FBB3C2         1
# ...                                        ...
# 5587B913-6EFA-4746-8BCC-0FE3CCE62805         9
# 2D4AE78B-F09A-4315-B8C6-9CB747C09B93         9
# AB33242F-4607-4E79-9EA0-4D1373E7927C        10
# 0E8FAB1A-53ED-4E1E-AB1D-D1065821ED07        11
# A321541E-966B-485B-87C2-9783FB0457F9        12
#
# [236802 rows x 1 columns]

# %%
from datetime import datetime

# %%
joined_df['merchant'].unique()
# Out:
# array(['Money Transfer', 'Digital Goods', 'Utility', 'Transportation',
#        'Marketplace', 'Entertainment', 'Food and Beverage',
#        'Retail Outlet', 'Supermarket & Convenience store',
#        'Business Service', 'Travel', 'Electronic Store', 'Clothing',
#        'Game', 'Lodging, Hotels & Accommodations', 'App Test'],
#       dtype=object)

# %%
joined_df[joined_df['transType'] == 6]
# Out:
#                                      deviceID          transID  transType  \
# 730      12548543-8A3B-4A93-A7B7-09FE276DBF0C  200818000228991          6
# 2414     3AADCCF3-3766-4926-A65D-35AB3FF52267  200804000718259          6
# 5788                         95bb6f8cf3cbe65e  200821000371227          6
# 7605     C91AA6A0-5572-49F7-93E9-6095BB0371E0  200809000002489          6
# 8784     E451FE8C-63D8-48A2-AE70-1419F2E47B22  200803000525477          6
# ...                                       ...              ...        ...
# 2154140  1C38ACA5-B05A-414B-AEDE-274EA5AD38B6  200804000106977          6
# 2159730  8E5EBB61-784B-4B1D-AF60-FD371B945127  200827000033180          6
# 2159993  975E23DA-34B1-46F6-B9D2-4A79F23140CB  200822000141049          6
# 2161456  BB831245-F719-4C97-AB5E-9852FB09CD47  200825000194074          6
# 2162974  DF15D23C-507F-46AE-A139-3078A7CC8F04  200804000700953          6
#
#          appid  pmcID  amount           userID           osVer   deviceModel  \
# 730          6     40  500000  180704000005138          13.3.1    iPhone11,6
# 2414         6     40   10000  200628000000434          11.4.1     iPhone7,2
# 5788         6     40  100000  180210000006997  Android 28 (9)  OPPO CPH2073
# 7605         6     40  200000  190701000002048          12.4.7     iPhone7,2
# 8784         6     40    1000  180825000002178            13.3    iPhone11,8
# ...        ...    ...     ...              ...             ...           ...
# 2154140      6     40    5000  190207000012296          13.5.1    iPhone12,1
# 2159730      6     40    2000  180815000000022          13.3.1     iPhone9,4
# 2159993      6     40    2000  191229000012821            13.6    iPhone12,5
# 2161456      6     40  600000  181024000003791          12.0.1     iPhone7,2
# 2162974      6     40    2020  200804001140006          13.4.1    iPhone10,5
#
#                  userIP                  reqDate  longitude  latitude  \
# 730       14.241.142.44  2020-08-18 15:53:08.571        NaN       NaN
# 2414       58.186.61.34  2020-08-04 22:38:34.277        NaN       NaN
# 5788     113.168.50.179  2020-08-21 23:25:22.751        NaN       NaN
# 7605      171.236.69.74  2020-08-09 00:06:25.329        NaN       NaN
# 8784     113.185.41.116  2020-08-03 20:07:20.467        NaN       NaN
# ...                 ...                      ...        ...       ...
# 2154140  171.253.29.255  2020-08-04 07:58:00.907        NaN       NaN
# 2159730  113.167.26.180  2020-08-27 06:09:18.258        NaN       NaN
# 2159993     27.64.43.13  2020-08-22 12:14:11.073        NaN       NaN
# 2161456  171.255.66.229  2020-08-25 14:17:21.426        NaN       NaN
# 2162974    27.65.18.160  2020-08-04 22:08:51.945        NaN       NaN
#
#          campaignID   type_transaction        merchant
# 730               0  sending_redpacket  Money Transfer
# 2414              0  sending_redpacket  Money Transfer
# 5788              0  sending_redpacket  Money Transfer
# 7605              0  sending_redpacket  Money Transfer
# 8784              0  sending_redpacket  Money Transfer
# ...             ...                ...             ...
# 2154140           0  sending_redpacket  Money Transfer
# 2159730           0  sending_redpacket  Money Transfer
# 2159993           0  sending_redpacket  Money Transfer
# 2161456           0  sending_redpacket  Money Transfer
# 2162974           0  sending_redpacket  Money Transfer
#
# [887 rows x 16 columns]

# %%
amount_temp = joined_df[joined_df['deviceID'] == 'A321541E-966B-485B-87C2-9783FB0457F9' & joined_df['transType']]
amount_temp.head()
# Out:
#                                      deviceID          transID  transType  \
# 1951685  A321541E-966B-485B-87C2-9783FB0457F9  200820000079622          1
# 1951708  A321541E-966B-485B-87C2-9783FB0457F9  200807000252754          1
# 1951710  A321541E-966B-485B-87C2-9783FB0457F9  200809000187436          1
# 1951724  A321541E-966B-485B-87C2-9783FB0457F9  200821000100989          1
# 1951730  A321541E-966B-485B-87C2-9783FB0457F9  200824000061319          1
#
#          appid  pmcID  amount           userID   osVer deviceModel  \
# 1951685    454     37  200000  190419000000211  12.1.3   iPhone8,2
# 1951708    454     37  100000  190419000000211  12.1.3   iPhone8,2
# 1951710    454     37  100000  190419000000211  12.1.3   iPhone8,2
# 1951724    454     37  200000  190419000000211  12.1.3   iPhone8,2
# 1951730    454     37  200000  190419000000211  12.1.3   iPhone8,2
#
#                  userIP                  reqDate   longitude   latitude  \
# 1951685  103.245.252.75  2020-08-20 09:00:58.437    0.000000   0.000000
# 1951708  103.245.252.19  2020-08-07 15:47:19.774    0.000000   0.000000
# 1951710    14.169.34.58  2020-08-09 16:42:30.015    0.000000   0.000000
# 1951724  103.245.252.76  2020-08-21 09:35:06.770  106.745651  10.757929
# 1951730  103.245.252.76  2020-08-24 08:33:22.159  106.745630  10.757932
#
#          campaignID type_transaction        merchant
# 1951685           0          payment  Money Transfer
# 1951708           0          payment  Money Transfer
# 1951710           0          payment  Money Transfer
# 1951724           0          payment  Money Transfer
# 1951730           0          payment  Money Transfer

# %%
amount_temp['reqDate'] = amount_temp['reqDate'].apply(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S.%f").date())
# Out:
# <ipython-input-63-ffb73e579f36>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amount_temp['reqDate'] = amount_temp['reqDate'].apply(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S.%f").date())

# %%
amount_temp.groupby('reqDate').agg({'amount': 'sum'})
# Out:
#             amount
# reqDate
# 2020-08-03  138000
# 2020-08-04  153500
# 2020-08-05  170500
# 2020-08-07  184500
# 2020-08-08   36000
# 2020-08-09  140000
# 2020-08-10   78200
# 2020-08-11   57800
# 2020-08-13   84000
# 2020-08-14  310300
# 2020-08-17   40000
# 2020-08-18  167600
# 2020-08-19   80500
# 2020-08-20  404600
# 2020-08-21  294600
# 2020-08-23  350260
# 2020-08-24  413000
# 2020-08-25   45500
# 2020-08-26  115400
# 2020-08-27  224500
# 2020-08-28   87000
# 2020-08-29  121400
# 2020-08-31   11000

# %%
df.loc[df['os_name'] == 'android'].groupby('hw_device_id').userId.count().sort_values()
# Out:
# hw_device_id
# 64fc764c6141f8bb     1
# 83f5548c361f0c09     1
# 83f54287569ea81c     1
# 83f32a1b10c12b63     1
# 83ef5adcc755dcd0     1
#                     ..
# ca06a6418f2482ed    29
# d775a3556b9ab2d6    30
# 45625b9901e2bc45    33
# 13942623531b1456    37
# 213d8639c4acde66    49
# Name: userId, Length: 26843, dtype: int64
