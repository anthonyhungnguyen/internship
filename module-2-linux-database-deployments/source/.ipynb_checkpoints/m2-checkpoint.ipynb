# %%
import pandas as pd
import datetime
from datetime import timedelta
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
df = pd.read_csv("vtf2020_module2_data.csv",  parse_dates=True)

# %%
df.count()
# Out:
# userID         2103296
# reqDate        2103296
# transID        2103296
# bankCode       1051478
# amount         2103296
# transStatus    2103296
# type           2103296
# dtype: int64

# %%
df['reqDate']
# Out:
# 0          2018-12-28 00:07:36.302
# 1          2018-12-28 00:08:35.218
# 2          2018-12-28 00:27:33.530
# 3          2018-12-28 01:00:55.220
# 4          2018-12-28 01:48:51.443
#                     ...
# 2103291    2018-12-14 13:17:52.888
# 2103292    2018-12-14 15:41:49.949
# 2103293    2018-12-30 08:57:41.758
# 2103294    2018-12-07 12:09:06.035
# 2103295    2018-12-06 19:37:38.320
# Name: reqDate, Length: 2103296, dtype: object

# %%
df['reqDate'] = df['reqDate'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S.%f').date())

# %% [markdown]
# # Bank Success Rate

# %%
df.loc[df['bankCode'] == 'BIDV']
# Out:
#                                    userID     reqDate          transID  \
# 899399   b65832ffed27be9673e83962da3da6c8  2018-12-20  181220000142753
# 1466314  15e59ee761c854df56df4ac4c896ff40  2018-12-24  181224000019983
# 1520545  30884aff88caa1497b5e248dbc99226e  2018-12-26  181226000126720
#
#         bankCode  amount  transStatus  type
# 899399      BIDV  790000            0   138
# 1466314     BIDV  117000            0    24
# 1520545     BIDV  239000            0   237

# %%
sorted_date = sorted(df['reqDate'].unique())

# %%
bank_success = df.groupby(['bankCode', 'reqDate']).agg({
    'transStatus': 'sum',
    'transID': 'count'
})

bank_success.columns = ['successTransactions', 'totalTransactions']
bank_success['SuccessRate'] = bank_success['successTransactions'] / bank_success['totalTransactions']
bank_success
# Out:
#                      successTransactions  totalTransactions  SuccessRate
# bankCode reqDate
# BIDV     2018-12-20                    0                  1     0.000000
#          2018-12-24                    0                  1     0.000000
#          2018-12-26                    0                  1     0.000000
# CC       2018-12-26                    0                  1     0.000000
#          2018-12-30                    0                  1     0.000000
# ...                                  ...                ...          ...
# ZPVCCB   2018-12-27                   52                 91     0.571429
#          2018-12-28                   63                 75     0.840000
#          2018-12-29                   28                 29     0.965517
#          2018-12-30                   24                 28     0.857143
#          2018-12-31                   19                 23     0.826087
#
# [291 rows x 3 columns]

# %%
bank_success_reset_index = bank_success.reset_index()
bank_success_reset_index
# Out:
#     bankCode     reqDate  successTransactions  totalTransactions  SuccessRate
# 0       BIDV  2018-12-20                    0                  1     0.000000
# 1       BIDV  2018-12-24                    0                  1     0.000000
# 2       BIDV  2018-12-26                    0                  1     0.000000
# 3         CC  2018-12-26                    0                  1     0.000000
# 4         CC  2018-12-30                    0                  1     0.000000
# ..       ...         ...                  ...                ...          ...
# 286   ZPVCCB  2018-12-27                   52                 91     0.571429
# 287   ZPVCCB  2018-12-28                   63                 75     0.840000
# 288   ZPVCCB  2018-12-29                   28                 29     0.965517
# 289   ZPVCCB  2018-12-30                   24                 28     0.857143
# 290   ZPVCCB  2018-12-31                   19                 23     0.826087
#
# [291 rows x 5 columns]

# %% [markdown]
# # RFM

# %%
max_date = max(df['reqDate'])
max_date
# Out:
# datetime.date(2018, 12, 31)

# %%
rfm = df.groupby(['userID']).agg({
    'reqDate': lambda x: (max_date + timedelta(1) - x.max()).days,
    'transID': 'count',
    'amount': 'sum'
})

# %%
rfm.columns = ['recency', 'frequency', 'monetary']

# %%
rfm['r-score'] = pd.qcut(rfm['recency'], q=4, labels=range(4, 0, -1))
rfm['f-score'] = pd.qcut(rfm['frequency'], q=4, labels=range(1, 5, 1))
rfm['m-score'] = pd.qcut(rfm['monetary'], q=4, labels=range(1, 5, 1))
rfm
# Out:
#                                   recency  frequency  monetary r-score  \
# userID
# 000084454cb2ae6275bb479b957d6b7b       18          7    591530       1
# 0000c78ffe9aaa92a4694f65e5465b24       11          2    350000       2
# 0000cce93f5aa9df5c0f5c9c002e2e75       20          2   1392600       1
# 0001081adfa0c6443ef076f85eeeee5c       11          3    383100       2
# 000169c037c452a0d0386f9d06933c5a        2         85  28827200       4
# ...                                   ...        ...       ...     ...
# ffffa20c3d0c58f41dec3c5e99f848b2        9          2    211000       2
# ffffa3034495807b1f393ef0a090d6e5        7          1    536000       3
# ffffb1a8994d83f712c2819ab5e97173       11          2     12000       2
# ffffe96889018bde56c719ae1b88711d       25          1    485000       1
# ffffe9cff443b9f021f1945a9b66ad8c        5          2    339000       3
#
#                                  f-score m-score
# userID
# 000084454cb2ae6275bb479b957d6b7b       3       3
# 0000c78ffe9aaa92a4694f65e5465b24       1       2
# 0000cce93f5aa9df5c0f5c9c002e2e75       1       4
# 0001081adfa0c6443ef076f85eeeee5c       2       2
# 000169c037c452a0d0386f9d06933c5a       4       4
# ...                                  ...     ...
# ffffa20c3d0c58f41dec3c5e99f848b2       1       2
# ffffa3034495807b1f393ef0a090d6e5       1       3
# ffffb1a8994d83f712c2819ab5e97173       1       1
# ffffe96889018bde56c719ae1b88711d       1       3
# ffffe9cff443b9f021f1945a9b66ad8c       1       2
#
# [311204 rows x 6 columns]

# %%
rfm['RFM-score'] = rfm['r-score'].astype(str) + rfm['f-score'].astype(str) + rfm['m-score'].astype(str)

# %%
rfm_reset_index = rfm.reset_index()

# %%
rfm_reset_index
# Out:
#                                   userID  recency  frequency  monetary  \
# 0       000084454cb2ae6275bb479b957d6b7b       18          7    591530
# 1       0000c78ffe9aaa92a4694f65e5465b24       11          2    350000
# 2       0000cce93f5aa9df5c0f5c9c002e2e75       20          2   1392600
# 3       0001081adfa0c6443ef076f85eeeee5c       11          3    383100
# 4       000169c037c452a0d0386f9d06933c5a        2         85  28827200
# ...                                  ...      ...        ...       ...
# 311199  ffffa20c3d0c58f41dec3c5e99f848b2        9          2    211000
# 311200  ffffa3034495807b1f393ef0a090d6e5        7          1    536000
# 311201  ffffb1a8994d83f712c2819ab5e97173       11          2     12000
# 311202  ffffe96889018bde56c719ae1b88711d       25          1    485000
# 311203  ffffe9cff443b9f021f1945a9b66ad8c        5          2    339000
#
#        r-score f-score m-score RFM-score
# 0            1       3       3       133
# 1            2       1       2       212
# 2            1       1       4       114
# 3            2       2       2       222
# 4            4       4       4       444
# ...        ...     ...     ...       ...
# 311199       2       1       2       212
# 311200       3       1       3       313
# 311201       2       1       1       211
# 311202       1       1       3       113
# 311203       3       1       2       312
#
# [311204 rows x 8 columns]

# %% [markdown]
# # AppID

# %%
appid = df.loc[~df['type'].isin([1,2,3,4])]
appid = appid.groupby(['userID', 'type']).agg({
    'amount': 'sum'
})
appid_reset_index = appid.reset_index()
appid[10:30]
# Out:
#                                         amount
# userID                           type
# 0001e384498697abaf4e4006be5d7a66 24     583567
# 0002af59815e210f0d57af3b01c89867 61      95500
# 00030aea176d5f2e42ed1653636d16cf 328    270000
# 000316e2888097423207f37eb2875b4f 17     328524
# 00031adec38699bb6ce08bb08b0336d7 264   1918000
# 000373ad46ba53bb4578b51eea6b8eeb 15      46750
# 00049122f3a8eea8e60ecc0d21a4acb5 12      38800
#                                  328    500000
# 0004aeb79a693350a1112beecd20557a 15     205700
# 0004d164c8d1181e78095cd3b8958d3f 15     130900
# 0004d8feabf597c267e7eadd389ff4bb 12     174700
#                                  328    250000
# 0004e9444cbf290c9d58eaa7746379dd 24     625850
# 0005860a6b765475002af7f4903463f9 17    5041828
# 0005f58f6e1477d2ede9933eb2fcc865 328    210000
# 0006544b05ceb936b9ea7b2af41e8f22 328    260000
# 00070538e72014e35760b46054c8fc84 24    2164000
# 000708e22b25c950d014c17e0424cbfb 15     187000
#                                  61     191000
#                                  69     955000

# %%
appid_reset_index
# Out:
#                                   userID  type  amount
# 0       000084454cb2ae6275bb479b957d6b7b    61  391530
# 1       0000c78ffe9aaa92a4694f65e5465b24   328  250000
# 2       0000cce93f5aa9df5c0f5c9c002e2e75   118  692600
# 3       0001081adfa0c6443ef076f85eeeee5c    12   97000
# 4       0001081adfa0c6443ef076f85eeeee5c    61  286100
# ...                                  ...   ...     ...
# 431079  ffffa20c3d0c58f41dec3c5e99f848b2    24  111000
# 431080  ffffa3034495807b1f393ef0a090d6e5   264  536000
# 431081  ffffe96889018bde56c719ae1b88711d    12  485000
# 431082  ffffe9cff443b9f021f1945a9b66ad8c    19  100000
# 431083  ffffe9cff443b9f021f1945a9b66ad8c   237  239000
#
# [431084 rows x 3 columns]

# %% [markdown]
# # Users Transfer

# %%
ut = pd.read_csv('transfer_network_201812.csv', parse_dates=True)
ut
# Out:
#                                   sender                          receiver  \
# 0       192614cd07e29f4f1f78da281ebeb7ef  b616ace146ca031bfd5b63f08be2ebb5
# 1       e230a20a8a1bdfb8a4ef7376689a92ae  0cb3c56df5febd13d5123e98f3031a06
# 2       8ccccf41e5d1db2a9c0c85580ba452a3  f1aea120ad4b1b901561c0cb69f5af78
# 3       177ad70e864b250986cd8cf9b6b445c0  5c98bc292facf20ee231c0e1602c29a1
# 4       b4fe7056bd4a9ba2bac7dbea137037db  a87188af4cd2e9707dc755f022d3b83c
# ...                                  ...                               ...
# 111246  aaada843937d95068536f9e7156678a9  0aae280061a6034e7fc6650013331bc9
# 111247  2bcdd979b7b22286ff31fe40b1d10159  89ad1e4da9219d6f7882f0afb963a0e1
# 111248  9101c2058fa8cd4e3316fd3facb6eb3d  ca2c5b84065e6efb059dec713b2188f5
# 111249  a398d9e85817730be11885d7137b1506  174dc3e94591b12d04e22ef73756e223
# 111250  f07058214b7e9ef0c9e476ec1b2da12f  8f641e9f5b18571c088150eafaf41010
#
#                 transID                  reqDate   amount     type
# 0       181227000016480  2018-12-27 04:46:59.009   100000  ZaloPay
# 1       181227000036940  2018-12-27 08:50:45.500    11000  ZaloPay
# 2       181227000039884  2018-12-27 09:05:58.860   102595  ZaloPay
# 3       181227000044600  2018-12-27 09:15:16.834  1820000  ZaloPay
# 4       181227000054879  2018-12-27 09:44:47.729     8000  ZaloPay
# ...                 ...                      ...      ...      ...
# 111246  181206000092235  2018-12-06 15:59:50.347   315000  ZaloPay
# 111247  181206000119710  2018-12-06 20:19:03.521   100000  ZaloPay
# 111248  181206000126342  2018-12-06 21:15:18.659   500000  ZaloPay
# 111249  181206000128069  2018-12-06 21:32:43.962   200000  ZaloPay
# 111250  181206000132530  2018-12-06 22:24:46.486  1500000  ZaloPay
#
# [111251 rows x 6 columns]

# %%
ut.groupby(['sender', 'receiver']).agg({
    'transID': 'count',
    'amount': 'sum'
})[:20]
# Out:
#                                                                    transID  \
# sender                           receiver
# 00055b984cdfbe6b799d5debf8323c64 43026332e53541a19627d074c1833200        1
# 0006544b05ceb936b9ea7b2af41e8f22 060c23c14d40d3e85d6054783db38a02        1
# 000708e22b25c950d014c17e0424cbfb 042c9ebffdff74530d48a92d3a6b9ea3        1
# 00085550d7aa4e4f322a79effc6cc3fc a6238e443bc03bfc46b3f6799c16ae2c        2
# 000c1d6349b283a51bc071e16a8ecb7a 9b3b61b0e9f6a17ad23750e4a6ad24a2        1
# 000d69f7c9ef2652b631062b6376c606 c23a13b8204936d5a0e581ca7c5c9307        1
# 000ea5580bdc773a6f7f3f77c8f11f17 c07123020748b6342ad5cafdc06662ab        1
# 000ec49f2c8a4f9882db8167f6cc4542 b766a2b2775712111f73c354b258e1a2        1
# 0010058c779f4507618e1a9d341e6929 1c54a9159553e1f321a9fa2b7f7e72b8        2
#                                  2606c7cba485fdbcd053fd9f01489ca6        2
#                                  38c3c93dd526169906502ccb6da73728        3
#                                  47637c3d45fcedf001b2abfd2b816386        5
#                                  48a919beaa05fa142d2b34afff4104ee        1
#                                  4a93308284a6b2bec87f66c93cee0c8e        2
#                                  5b60586743c8388e80ea2385a824d3f1        3
#                                  8a03d56bb4e2900b6ac6c9baa6a8981d        6
#                                  8b875b5820cbce420f0cb90ead239386        2
#                                  a123b062e583da77f241fe681dfec1bd        1
#                                  a58b34ce9651d0dd4a00a994806b586d        1
#                                  b9cde4f6e92d5daff00ecafd9e4f06f3        2
#
#                                                                     amount
# sender                           receiver
# 00055b984cdfbe6b799d5debf8323c64 43026332e53541a19627d074c1833200     1500
# 0006544b05ceb936b9ea7b2af41e8f22 060c23c14d40d3e85d6054783db38a02    20000
# 000708e22b25c950d014c17e0424cbfb 042c9ebffdff74530d48a92d3a6b9ea3   500000
# 00085550d7aa4e4f322a79effc6cc3fc a6238e443bc03bfc46b3f6799c16ae2c  1033143
# 000c1d6349b283a51bc071e16a8ecb7a 9b3b61b0e9f6a17ad23750e4a6ad24a2   300000
# 000d69f7c9ef2652b631062b6376c606 c23a13b8204936d5a0e581ca7c5c9307   227000
# 000ea5580bdc773a6f7f3f77c8f11f17 c07123020748b6342ad5cafdc06662ab    25000
# 000ec49f2c8a4f9882db8167f6cc4542 b766a2b2775712111f73c354b258e1a2    50000
# 0010058c779f4507618e1a9d341e6929 1c54a9159553e1f321a9fa2b7f7e72b8   201000
#                                  2606c7cba485fdbcd053fd9f01489ca6   163500
#                                  38c3c93dd526169906502ccb6da73728   310000
#                                  47637c3d45fcedf001b2abfd2b816386   492500
#                                  48a919beaa05fa142d2b34afff4104ee   138461
#                                  4a93308284a6b2bec87f66c93cee0c8e   472667
#                                  5b60586743c8388e80ea2385a824d3f1   116000
#                                  8a03d56bb4e2900b6ac6c9baa6a8981d  1740000
#                                  8b875b5820cbce420f0cb90ead239386   100000
#                                  a123b062e583da77f241fe681dfec1bd    30000
#                                  a58b34ce9651d0dd4a00a994806b586d  1300000
#                                  b9cde4f6e92d5daff00ecafd9e4f06f3    85000
